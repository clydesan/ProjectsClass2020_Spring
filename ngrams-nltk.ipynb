# %%
# ngrams-nltk

from urllib.request import urlopen
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import sent_tokenize
from nltk.util import ngrams
import re

gnum = 2 # gnum-grams: 2grams, 3grams, etc

stops = set(stopwords.words('english')) 

content = str(
      urlopen('http://pythonscraping.com/files/inaugurationSpeech.txt').read(),
              'utf-8')
content = content.lower()
content = re.sub('\n', ' ', content)
content = bytes(content, 'UTF-8')
content = content.decode('ascii', 'ignore')
sentences = sent_tokenize(content)
xgrams = Counter()

# remove all characters except alphabetic and apostrophes
tokenizer = RegexpTokenizer(r"[\w'`]+")
for sent in sentences:
    sent = tokenizer.tokenize(sent)
    for ngram in ngrams(sent, gnum):
        good = True
        for ig in range(gnum):
            if ngram[ig] in stops:
                good = False
                break
        if good:
            xgrams.update([ngram])
print(len(xgrams), '{}grams'.format(gnum))
print(xgrams)
# Out:
# 1064 2grams
# Counter({('fellow', 'citizens'): 11, ('united', 'states'): 10, ('executive', 'department'): 4, ('general', 'government'): 4, ('called', 'upon'): 3, ('chief', 'magistrate'): 3, ('american', 'citizen'): 3, ('mr', 'jefferson'): 3, ('legislative', 'body'): 3, ('whole', 'country'): 3, ('express', 'grant'): 2, ('several', 'departments'): 2, ('one', 'time'): 2, ('upon', 'another'): 2, ('reserved', 'rights'): 2, ('federal', 'government'): 2, ('heretofore', 'given'): 2, ('pristine', 'health'): 2, ('second', 'term'): 2, ('observed', 'however'): 2, ('foreign', 'relations'): 2, ('executive', 'power'): 2, ('negative', 'upon'): 2, ('declare', 'void'): 2, ('state', 'governments'): 2, ('immediate', 'representatives'): 2, ('veto', 'power'): 2, ('high', 'office'): 2, ('disputed', 'points'): 2, ('respectively', 'claim'): 2, ('reserved', 'powers'): 2, ('state', 'authorities'): 2, ('great', 'increase'): 2, ('elective', 'franchise'): 2, ('strange', 'indeed'): 2, ('public', 'money'): 2, ('religious', 'liberty'): 2, ('propose', 'amendments'): 2, ('exclusive', 'metallic'): 2, ('metallic', 'currency'): 2, ('american', 'citizens'): 2, ('one', 'state'): 2, ('domestic', 'concerns'): 2, ('foreign', 'aggression'): 2, ('individual', 'members'): 2, ('free', 'people'): 2, ('well', 'established'): 2, ('genuine', 'spirit'): 2, ('true', 'spirit'): 2, ('chief', 'executive'): 1, ('executive', 'office'): 1, ('free', 'nation'): 1, ('constitution', 'prescribes'): 1, ('necessary', 'qualification'): 1, ('custom', 'coeval'): 1, ('roman', 'consul'): 1, ('early', 'period'): 1, ('celebrated', 'republic'): 1, ('striking', 'contrast'): 1, ('seldom', 'carr